# %% [markdown]
# ## Loading Data

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Explore Data Analysis

# %%
clients = pd.read_csv('Clients_csv.csv')
clients
# Out:
# /tmp/ipykernel_68022/2028699144.py:1: DtypeWarning: Columns (0,1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   clients = pd.read_csv('Clients_csv.csv')
#                 ParcelID                                OwnerName  \
# 0        092 04 0 308.00            E3 CONSTRUCTION SERVICES, LLC
# 1        092 04 0 309.00            E3 CONSTRUCTION SERVICES, LLC
# 2        018 16 0 208.00                           HARR, SCOTT W.
# 3        025 16 0 002.00  JESUS CHRIST UPLIFTING COMMUNITY CHURCH
# 4        042 09 0 002.00           LORD'S FRIENDLY MISSION CHURCH
# ...                  ...                                      ...
# 1048570              NaN                                      NaN
# 1048571              NaN                                      NaN
# 1048572              NaN                                      NaN
# 1048573              NaN                                      NaN
# ...

# %%
units = pd.read_csv('Units-csv.csv')
units
# Out:
#        UniqueID                       PropertyAddress  \
# 0           2045   1808  FOX CHASE DR, GOODLETTSVILLE
# 1          16918   1832  FOX CHASE DR, GOODLETTSVILLE
# 2          54582   1864 FOX CHASE  DR, GOODLETTSVILLE
# 3          43070   1853  FOX CHASE DR, GOODLETTSVILLE
# 4          22714   1829  FOX CHASE DR, GOODLETTSVILLE
# ...          ...                                  ...
# 56472      30469  1435  WINDING CREEK DR, NOLENSVILLE
# 56473      27707  1423  WINDING CREEK DR, NOLENSVILLE
# 56474      52709    1804 GRACE POINT  LN, NOLENSVILLE
# 56475      54042   1709 PARK TERRACE  LN, NOLENSVILLE
# 56476      54043   1713 PARK TERRACE  LN, NOLENSVILLE
#
#                        LandUse SalePrice       SaleDate  LandValue  \
# 0                SINGLE FAMILY    240000  April 9, 2013    50000.0
# 1                SINGLE FAMILY    366000      10-Jun-14    50000.0
# 2                SINGLE FAMILY    435000      26-Sep-16    50000.0
# ...

# %%
units.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56477 entries, 0 to 56476
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         56477 non-null  int64
#  1   PropertyAddress  56448 non-null  object
#  2   LandUse          56477 non-null  object
#  3   SalePrice        56477 non-null  object
#  4   SaleDate         56477 non-null  object
#  5   LandValue        26015 non-null  float64
#  6   BuildingValue    26015 non-null  float64
#  7   TotalValue       26015 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 3.4+ MB

# %%
units['PropertyAddress'].isna().value_counts()
# Out:
# PropertyAddress
# False    56448
# True        29
# Name: count, dtype: int64

# %%
units['LandUse'].isna().value_counts()
# Out:
# LandUse
# False    56477
# Name: count, dtype: int64

# %%
units['BuildingValue'].isna().value_counts()
# Out:
# BuildingValue
# True     30462
# False    26015
# Name: count, dtype: int64

# %%
units['SaleDate'].isna().value_counts()
# Out:
# SaleDate
# False    56477
# Name: count, dtype: int64

# %%
units['LandValue'].isna().value_counts()
# Out:
# LandValue
# True     30462
# False    26015
# Name: count, dtype: int64

# %%
units['TotalValue'].isna().value_counts()
# Out:
# TotalValue
# True     30462
# False    26015
# Name: count, dtype: int64

# %%
units.columns
# Out:
# Index(['UniqueID ', 'PropertyAddress', 'LandUse', 'SalePrice', 'SaleDate',
#        'LandValue', 'BuildingValue', 'TotalValue'],
#       dtype='object')

# %%
# Out:
# 0      240000
# 1      366000
# 2      435000
# 3      255000
# 4      278000
#         ...
# 295    152000
# 296    142500
# 297    124900
# 298    160000
# 299    167000
# Name: SalePrice, Length: 300, dtype: object

# %% [markdown]
# # =========================================================================

# %%
units_clean = units
units_clean       # haven't nul
# Out:
#        UniqueID                       PropertyAddress  \
# 0           2045   1808  FOX CHASE DR, GOODLETTSVILLE
# 1          16918   1832  FOX CHASE DR, GOODLETTSVILLE
# 2          54582   1864 FOX CHASE  DR, GOODLETTSVILLE
# 3          43070   1853  FOX CHASE DR, GOODLETTSVILLE
# 4          22714   1829  FOX CHASE DR, GOODLETTSVILLE
# ...          ...                                  ...
# 56472      30469  1435  WINDING CREEK DR, NOLENSVILLE
# 56473      27707  1423  WINDING CREEK DR, NOLENSVILLE
# 56474      52709    1804 GRACE POINT  LN, NOLENSVILLE
# 56475      54042   1709 PARK TERRACE  LN, NOLENSVILLE
# 56476      54043   1713 PARK TERRACE  LN, NOLENSVILLE
#
#                        LandUse SalePrice       SaleDate  LandValue  \
# 0                SINGLE FAMILY    240000  April 9, 2013    50000.0
# 1                SINGLE FAMILY    366000      10-Jun-14    50000.0
# 2                SINGLE FAMILY    435000      26-Sep-16    50000.0
# ...

# %%
units['BuildingValue'].mean()
# Out:
# 160784.67710936

# %%
units['LandValue'].mean()
# Out:
# 69068.55760138381

# %%
units_clean['SalePrice'] = units['SalePrice'].str.replace('$', '', regex=False).str.replace(',', '', regex=False).astype(float)

# %%
units_clean['SalePrice'].mean()
# Out:
# 327226.36956637213

# %%
units['TotalValue'].mean().round(2)
# Out:
# 232375.4

# %%
units_clean['SalePrice'].describe()
# Out:
# count    5.647700e+04
# mean     3.272264e+05
# std      9.298326e+05
# min      5.000000e+01
# 25%      1.350000e+05
# 50%      2.051000e+05
# 75%      3.285000e+05
# max      5.427806e+07
# Name: SalePrice, dtype: float64

# %% [markdown]
# # fill null value of [BuildingValue,LandValue,TotalValue] by mean

# %%
units_clean['BuildingValue'] = units_clean['BuildingValue'].fillna(units['BuildingValue'].mean().round(2))
units_clean['LandValue'] = units_clean['LandValue'].fillna(units['LandValue'].mean().round(2))
units_clean['TotalValue'] = units_clean['TotalValue'].fillna(units['TotalValue'].mean().round(2))

# %%
copy_data = units_clean.dropna()
copy_data
# Out:
#        UniqueID                       PropertyAddress  \
# 0           2045   1808  FOX CHASE DR, GOODLETTSVILLE
# 1          16918   1832  FOX CHASE DR, GOODLETTSVILLE
# 2          54582   1864 FOX CHASE  DR, GOODLETTSVILLE
# 3          43070   1853  FOX CHASE DR, GOODLETTSVILLE
# 4          22714   1829  FOX CHASE DR, GOODLETTSVILLE
# ...          ...                                  ...
# 56472      30469  1435  WINDING CREEK DR, NOLENSVILLE
# 56473      27707  1423  WINDING CREEK DR, NOLENSVILLE
# 56474      52709    1804 GRACE POINT  LN, NOLENSVILLE
# 56475      54042   1709 PARK TERRACE  LN, NOLENSVILLE
# 56476      54043   1713 PARK TERRACE  LN, NOLENSVILLE
#
#                        LandUse  SalePrice       SaleDate  LandValue  \
# 0                SINGLE FAMILY   240000.0  April 9, 2013   50000.00
# 1                SINGLE FAMILY   366000.0      10-Jun-14   50000.00
# 2                SINGLE FAMILY   435000.0      26-Sep-16   50000.00
# ...

# %%
units_clean.describe()
# Out:
#           UniqueID      SalePrice     LandValue  BuildingValue    TotalValue
# count  56477.000000  5.647700e+04  5.647700e+04   5.647700e+04  5.647700e+04
# mean   28334.001133  3.272264e+05  6.906856e+04   1.607847e+05  2.323754e+05
# std    16352.590651  9.298326e+05  7.196840e+04   1.403530e+05  1.907556e+05
# min        0.000000  5.000000e+01  1.000000e+02   0.000000e+00  1.000000e+02
# 25%    14186.000000  1.350000e+05  3.000000e+04   1.188000e+05  1.599000e+05
# 50%    28313.000000  2.051000e+05  6.906856e+04   1.607847e+05  2.323754e+05
# 75%    42513.000000  3.285000e+05  6.906856e+04   1.607847e+05  2.323754e+05
# max    56635.000000  5.427806e+07  2.772000e+06   1.297180e+07  1.394040e+07

# %%
units_clean['PropertyAddress'].isna().value_counts()
# Out:
# PropertyAddress
# False    56448
# True        29
# Name: count, dtype: int64

# %%
copy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56448 entries, 0 to 56476
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UniqueID           56448 non-null  int64
#  1   PropertyAddress    56448 non-null  object
#  2   LandUse            56448 non-null  object
#  3   SalePrice          56448 non-null  float64
#  4   SaleDate           5220 non-null   datetime64[ns]
#  5   LandValue          56448 non-null  float64
#  6   BuildingValue      56448 non-null  float64
#  7   TotalValue         56448 non-null  float64
#  8   FormattedSaleDate  5220 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(3)
# memory usage: 4.3+ MB

# %%
copy_data.to_csv('Data_Cleaned.csv')

# %%
copy_data['SaleDate']
# Out:
# 0        April 9, 2013
# 1            10-Jun-14
# 2            26-Sep-16
# 3            29-Jan-16
# 4            10-Oct-14
#              ...
# 56472        27-May-15
# 56473         2-Mar-15
# 56474        16-Aug-16
# 56475         7-Sep-16
# 56476         7-Sep-16
# Name: SaleDate, Length: 56448, dtype: object

# %%
copy = copy_data.copy()

# %%
copy['SaleDate']
# Out:
# 0        April 9, 2013
# 1            10-Jun-14
# 2            26-Sep-16
# 3            29-Jan-16
# 4            10-Oct-14
#              ...
# 56472        27-May-15
# 56473         2-Mar-15
# 56474        16-Aug-16
# 56475         7-Sep-16
# 56476         7-Sep-16
# Name: SaleDate, Length: 56448, dtype: object

# %%
df  = copy.copy()
df
# Out:
#        UniqueID                       PropertyAddress  \
# 0           2045   1808  FOX CHASE DR, GOODLETTSVILLE
# 1          16918   1832  FOX CHASE DR, GOODLETTSVILLE
# 2          54582   1864 FOX CHASE  DR, GOODLETTSVILLE
# 3          43070   1853  FOX CHASE DR, GOODLETTSVILLE
# 4          22714   1829  FOX CHASE DR, GOODLETTSVILLE
# ...          ...                                  ...
# 56472      30469  1435  WINDING CREEK DR, NOLENSVILLE
# 56473      27707  1423  WINDING CREEK DR, NOLENSVILLE
# 56474      52709    1804 GRACE POINT  LN, NOLENSVILLE
# 56475      54042   1709 PARK TERRACE  LN, NOLENSVILLE
# 56476      54043   1713 PARK TERRACE  LN, NOLENSVILLE
#
#                        LandUse  SalePrice       SaleDate  LandValue  \
# 0                SINGLE FAMILY   240000.0  April 9, 2013   50000.00
# 1                SINGLE FAMILY   366000.0      10-Jun-14   50000.00
# 2                SINGLE FAMILY   435000.0      26-Sep-16   50000.00
# ...

# %%
df
# Out:
#        UniqueID                       PropertyAddress  \
# 0           2045   1808  FOX CHASE DR, GOODLETTSVILLE
# 1          16918   1832  FOX CHASE DR, GOODLETTSVILLE
# 2          54582   1864 FOX CHASE  DR, GOODLETTSVILLE
# 3          43070   1853  FOX CHASE DR, GOODLETTSVILLE
# 4          22714   1829  FOX CHASE DR, GOODLETTSVILLE
# ...          ...                                  ...
# 56472      30469  1435  WINDING CREEK DR, NOLENSVILLE
# 56473      27707  1423  WINDING CREEK DR, NOLENSVILLE
# 56474      52709    1804 GRACE POINT  LN, NOLENSVILLE
# 56475      54042   1709 PARK TERRACE  LN, NOLENSVILLE
# 56476      54043   1713 PARK TERRACE  LN, NOLENSVILLE
#
#                        LandUse  SalePrice       SaleDate  LandValue  \
# 0                SINGLE FAMILY   240000.0  April 9, 2013   50000.00
# 1                SINGLE FAMILY   366000.0      10-Jun-14   50000.00
# 2                SINGLE FAMILY   435000.0      26-Sep-16   50000.00
# ...

# %%
df.reset_index(drop=True, inplace=True)

# Function to check if a value is a string and try converting to datetime
def convert_to_date(value):
    if isinstance(value, str):  # Check if the value is a string
        try:
            # Convert string to datetime and then format as MM/DD/YYYY
            return pd.to_datetime(value).strftime('%-m/%-d/%Y')  # For Unix/Mac
            # return pd.to_datetime(value).strftime('%#m/%#d/%Y')  # For Windows
        except ValueError:
            return value  # If conversion fails, return the original value
    return value

# Apply the conversion function to each row in the 'SaleDate' column
for i in range(len(df['SaleDate'])):
    df.at[i, 'SaleDate'] = convert_to_date(df.at[i, 'SaleDate'])

# %% [markdown]
# # handell missing value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56448 entries, 0 to 56447
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         56448 non-null  int64
#  1   PropertyAddress  56448 non-null  object
#  2   LandUse          56448 non-null  object
#  3   SalePrice        56448 non-null  float64
#  4   SaleDate         56448 non-null  datetime64[ns]
#  5   LandValue        56448 non-null  float64
#  6   BuildingValue    56448 non-null  float64
#  7   TotalValue       56448 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(2)
# memory usage: 3.4+ MB

# %%
df['SaleDate'] = df['SaleDate'].apply(convert_to_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56448 entries, 0 to 56447
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         56448 non-null  int64
#  1   PropertyAddress  56448 non-null  object
#  2   LandUse          56448 non-null  object
#  3   SalePrice        56448 non-null  float64
#  4   SaleDate         56448 non-null  datetime64[ns]
#  5   LandValue        56448 non-null  float64
#  6   BuildingValue    56448 non-null  float64
#  7   TotalValue       56448 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(2)
# memory usage: 3.4+ MB

# %%
df['SaleDate'] = pd.to_datetime(df['SaleDate'], errors='coerce')

# %%
df['PropertyAddress'] = df['PropertyAddress'].astype(str)
df['LandUse'] = df['LandUse'].astype(str)

# %%
df.to_csv('Data_Cleaned_01.csv')
